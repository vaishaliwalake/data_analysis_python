# %%
import pandas as pd 
df = pd.read_csv("/Users/tanvi/Downloads/avocado.csv")
df

df['AveragePrice'].head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
df.AveragePrice.head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
albany_df = df[df['region']=="Albany"]

# %%
albany_df = df[ df['region'] == "Albany" ]
albany_df.set_index("Date", inplace=True)
albany_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# 2015-12-20  conventional  2015  Albany
# 2015-12-13  conventional  2015  Albany
# 2015-12-06  conventional  2015  Albany
# 2015-11-29  conventional  2015  Albany

# %%
albany_df = albany_df.set_index("Date")
albany_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-4836b22d311b> in <module>
# ----> 1 albany_df = albany_df.set_index("Date")
#       2 albany_df.head()
#
# ~/env/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
albany_df = albany_df.set_index("Date")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-de5c89b2f439> in <module>
# ----> 1 albany_df = albany_df.set_index("Date")
#
# ~/env/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
albany_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# 2015-12-20  conventional  2015  Albany
# 2015-12-13  conventional  2015  Albany
# 2015-12-06  conventional  2015  Albany
# 2015-11-29  conventional  2015  Albany

# %%
albany_df.set_index("Date", inplace=True)

albany_df['AveragePrice'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-75e56a791bf3> in <module>
# ----> 1 albany_df.set_index("Date", inplace=True)
#       2
#       3 albany_df['AveragePrice'].plot()
#       4
#
# ~/env/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
albany_df['AveragePrice'].plot()

# %%
albany_df.set_index("Date", inplace=True)
albany_df["AveragePrice"].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-fc9d9f5bbf98> in <module>
# ----> 1 albany_df.set_index("Date", inplace=True)
#       2 albany_df["AveragePrice"].plot()
#
# ~/env/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()

# %%
albany_df["AveragePrice"].plot()

# %%
albany_df.sort_index(inplace=True)

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()
